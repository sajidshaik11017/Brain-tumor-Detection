# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import os
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import cv2

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import VGG19
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# %%
data_path = 'C:\pythonn\brain_tumor/'

# %%
def main(data_path):
    filepaths = []
    labels = []
    classes_list = sorted(os.listdir(data_path))

    for s_class in classes_list:
        
        label = s_class
        classpath = os.path.join(data_path, s_class)
        flist = sorted(os.listdir(classpath))
        
        for file in flist:
            file_path = os.path.join(classpath, file)
            filepaths.append(file_path)
            labels.append(label)

    train_df = pd.DataFrame({
        'image_path': filepaths,
        'label': labels
    })
    
    return train_df

# %%
data_df = main(data_path)

# %%
data_df.head()
# Out:
#                                           image_path           label
# 0  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 1  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 2  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 3  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 4  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1

# %%
num_classes = len(data_df['label'].unique())
print(f"We have {num_classes} classes")
print(f"We have {data_df.shape[0]} images")
# Out:
# We have 44 classes
# We have 4479 images

# %%
data_df['label'].value_counts()
# Out:
# Meningioma T1C+           369
# Meningioma T1             272
# _NORMAL T2                271
# _NORMAL T1                251
# Astrocitoma T1C+          233
# Meningioma T2             233
# Neurocitoma T1C+          223
# Schwannoma T1C+           194
# Astrocitoma T1            176
# Astrocitoma T2            171
# Schwannoma T1             148
# Neurocitoma T1            130
# Schwannoma T2             123
# Carcinoma T1C+            112
# Papiloma T1C+             108
# Neurocitoma T2            104
# Glioblastoma T1C+          94
# Oligodendroglioma T1       86
# Tuberculoma T1C+           84
# Carcinoma T2               73
# Oligodendroglioma T1C+     72
# Meduloblastoma T1C+        67
# Papiloma T1                66
# Oligodendroglioma T2       66
# Carcinoma T1               66
# Papiloma T2                63
# Ependimoma T2              57
# Glioblastoma T2            55
# Glioblastoma T1            55
# Ependimoma T1C+            48
# Ependimoma T1              45
# Meduloblastoma T2          41
# Germinoma T1C+             40
# Tuberculoma T2             33
# Germinoma T2               33
# Granuloma T1C+             31
# Granuloma T1               30
# Tuberculoma T1             28
# Germinoma T1               27
# Ganglioglioma T2           23
# Meduloblastoma T1          23
# Ganglioglioma T1           20
# Ganglioglioma T1C+         18
# Granuloma T2               17
# Name: label, dtype: int64

# %%
import plotly.express as px
import plotly.graph_objs as go

def count_plot(x, title, xlabel, ylabel, width, length, order, rotation=True, palette='winter'):
    
    fig = px.histogram(x=x, color_discrete_sequence=px.colors.qualitative.Plotly, 
                       color=x, nbins=len(set(x)), template='simple_white')
    
    fig.update_layout(title=title, width=width, height=length, 
                      xaxis_title=xlabel, yaxis_title=ylabel,
                      font=dict(size=20))
    
    if rotation:
        fig.update_layout(xaxis_tickangle=-45)
    
    fig.show()

# %%
x = data_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Train Data)", "Label", 'Frequency', 800,600, order=order, rotation = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7a419549-d272-485d-aca3-57481bdbacbc" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a419549-d272-485d-aca3-57481bdbacbc")) {                    Plotly.newPlot(                        "7a419549-d272-485d-aca3-57481bdbacbc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Astrocitoma T1<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Astrocitoma T1","marker":{"color":"#636EFA","pattern":{"shape":""}},"name":"Astrocitoma T1","nbinsx":44,"offsetgroup":"Astrocitoma T1","orientation":"v","showlegend":true,"x":["Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1","Astrocitoma T1"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Astrocitoma T1C+<br>x=%{x}<br>count=%{y}<extra></extra>","l ...

# %%
test_split_size = 0.3
train_df, test_df = train_test_split(data_df, test_size=test_split_size, shuffle=True, random_state=123, stratify=data_df['label'])
test_df, valid_df = train_test_split(test_df, test_size=0.5, shuffle=True, random_state=123, stratify=test_df['label'])

# %%
train_df.head()
# Out:
#                                              image_path            label
# 2175  /kaggle/input/brain-tumor-mri-images-44c/Menin...  Meningioma T1C+
# 1735  /kaggle/input/brain-tumor-mri-images-44c/Menin...    Meningioma T1
# 1191  /kaggle/input/brain-tumor-mri-images-44c/Gliob...  Glioblastoma T1
# 129   /kaggle/input/brain-tumor-mri-images-44c/Astro...   Astrocitoma T1
# 1645  /kaggle/input/brain-tumor-mri-images-44c/Menin...    Meningioma T1

# %%
test_df.head()
# Out:
#                                              image_path             label
# 3506  /kaggle/input/brain-tumor-mri-images-44c/Schwa...   Schwannoma T1C+
# 1822  /kaggle/input/brain-tumor-mri-images-44c/Menin...     Meningioma T1
# 3265  /kaggle/input/brain-tumor-mri-images-44c/Papil...     Papiloma T1C+
# 4371  /kaggle/input/brain-tumor-mri-images-44c/_NORM...        _NORMAL T2
# 244   /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1C+

# %%
valid_df.head()
# Out:
#                                              image_path             label
# 3652  /kaggle/input/brain-tumor-mri-images-44c/Schwa...   Schwannoma T1C+
# 300   /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1C+
# 481   /kaggle/input/brain-tumor-mri-images-44c/Astro...    Astrocitoma T2
# 4051  /kaggle/input/brain-tumor-mri-images-44c/_NORM...        _NORMAL T1
# 892   /kaggle/input/brain-tumor-mri-images-44c/Epend...   Ependimoma T1C+

# %%
print(f"We have {len(train_df)} images in the training dataset\nWe have {len(valid_df)} images in the validating dataset\nWe have {len(test_df)} images in the testing dataset")
# Out:
# We have 3135 images in the training dataset
# We have 672 images in the validating dataset
# We have 672 images in the testing dataset

# %%
x = train_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Train Data)", "Label", 'Frequency', 800,600, rotation = True, order=order)
# Out:
# <div>                            <div id="210f1fcd-c5ca-4a70-899f-150553c596c0" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("210f1fcd-c5ca-4a70-899f-150553c596c0")) {                    Plotly.newPlot(                        "210f1fcd-c5ca-4a70-899f-150553c596c0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Meningioma T1C+<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Meningioma T1C+","marker":{"color":"#636EFA","pattern":{"shape":""}},"name":"Meningioma T1C+","nbinsx":44,"offsetgroup":"Meningioma T1C+","orientation":"v","showlegend":true,"x":["Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meningioma T1C+","Meni ...

# %%
x = valid_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Valid Data)", "Label", 'Frequency', 800,600, rotation = True, order=order)
# Out:
# <div>                            <div id="ceeb9d2f-16b0-4194-aa95-b81d2c25283d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ceeb9d2f-16b0-4194-aa95-b81d2c25283d")) {                    Plotly.newPlot(                        "ceeb9d2f-16b0-4194-aa95-b81d2c25283d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Schwannoma T1C+<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Schwannoma T1C+","marker":{"color":"#636EFA","pattern":{"shape":""}},"name":"Schwannoma T1C+","nbinsx":44,"offsetgroup":"Schwannoma T1C+","orientation":"v","showlegend":true,"x":["Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Astrocitoma T1C+<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Astrocitoma T1C+","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Astrocitoma T1C+","nbinsx":44,"offsetgroup":"Astrocitoma T1C+","orientation":"v","showlegend":true,"x":["Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+","Astrocitoma T1C+"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Astrocitoma T2<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Astrocitoma T2","marker":{"color":"#00CC96","pattern":{"shape":""}},"name":"Astrocitoma T2","nbinsx":44,"offsetgroup":"Astrocitoma T2","orientation":"v","showlegend":true,"x":["Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2","Astrocitoma T2"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=_NORMAL T1<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"_NORMAL T1","marker":{"color":"#AB63FA","pattern":{"shape":""}},"name":"_NORMAL T1","nbinsx":44,"offsetgroup":"_NORMAL T1","orientation":"v","showlegend":true,"x":["_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NORMAL T1","_NO ...

# %%
x = test_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Test Data)", "Label", 'Frequency', 800,600, rotation = True, order=order)
# Out:
# <div>                            <div id="a2f11326-fe4b-45e4-8477-97e1d299c7da" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2f11326-fe4b-45e4-8477-97e1d299c7da")) {                    Plotly.newPlot(                        "a2f11326-fe4b-45e4-8477-97e1d299c7da",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Schwannoma T1C+<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Schwannoma T1C+","marker":{"color":"#636EFA","pattern":{"shape":""}},"name":"Schwannoma T1C+","nbinsx":44,"offsetgroup":"Schwannoma T1C+","orientation":"v","showlegend":true,"x":["Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+","Schwannoma T1C+"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Meningioma T1<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Meningioma T1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Meningioma T1","nbinsx":44,"offsetgroup":"Meningioma T1","orientation":"v","showlegend":true,"x":["Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1","Meningioma T1"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Papiloma T1C+<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Papiloma T1C+","marker":{"color":"#00CC96","pattern":{"shape":""}},"name":"Papiloma T1C+","nbinsx":44,"offsetgroup":"Papiloma T1C+","orientation":"v","showlegend":true,"x":["Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+","Papiloma T1C+"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=_NORMAL T2<br>x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"_NORMAL T2","marker":{"color":"#AB63FA","pattern":{"shape":""}},"name":"_NORMAL T2","nbinsx":44,"offsetgroup":"_NORMAL T2","orientation":"v","showlegend":true,"x":["_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2","_NORMAL T2"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=Astrocitoma T1C+<br>x=%{x}<br>count=%{y}<e ...

# %%
def get_images_avg_width_height(df):
    
    avg_width, avg_height = 0,0
    for i in df.index:
        
        try:
            img_path = df['image_path'].loc[i]
            img = cv2.imread(img_path)
            avg_width += img.shape[0]
            avg_height += img.shape[1]
        except:
            pass

    avg_width // len(df)
    avg_height // len(df)
    
    return avg_width, avg_height

# %%
len(data_df)
# Out:
# 4479

# %%
data_avg_width, data_avg_height = get_images_avg_width_height(data_df)
print(f"Average width and height for the dataset is {data_avg_width//len(data_df)}x{data_avg_height//len(data_df)} with aspect_ratio {data_avg_width/data_avg_height}")
# Out:
# Average width and height for the dataset is 607x567 with aspect_ratio 1.0706256936627756

# %%
img_size = (224, 224)
channels = 3
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)
batch_size = 32
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size
def scalar(img):
    return img

# %%
tr_gen = ImageDataGenerator(preprocessing_function= scalar, 
                            horizontal_flip= True)

ts_gen = ImageDataGenerator(preprocessing_function= scalar)

train_gen = tr_gen.flow_from_dataframe( train_df, 
                                       x_col= 'image_path', 
                                       y_col= 'label', 
                                       target_size= img_size, 
                                       class_mode= 'categorical',
                                       color_mode= color, 
                                       shuffle= True, 
                                       batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df, 
                                       x_col= 'image_path', 
                                       y_col= 'label', 
                                       target_size= img_size, 
                                       class_mode= 'categorical',
                                       color_mode= color, 
                                       shuffle= True, 
                                       batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df, 
                                      x_col= 'image_path', 
                                      y_col= 'label', 
                                      target_size= img_size, 
                                      class_mode= 'categorical',
                                      color_mode= color, 
                                      shuffle= False, 
                                      batch_size= test_batch_size)
# Out:
# Found 3134 validated image filenames belonging to 44 classes.
# /opt/conda/lib/python3.7/site-packages/keras/preprocessing/image.py:1139: UserWarning:
#
# Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
# Found 672 validated image filenames belonging to 44 classes.
# Found 672 validated image filenames belonging to 44 classes.

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
base_model = tf.keras.applications.VGG19(include_top= False, weights= "imagenet", 
                                         input_shape= img_shape,pooling= 'max')

model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, 
          kernel_regularizer= regularizers.l2(l= 0.016), 
          activity_regularizer= regularizers.l1(0.006),
          bias_regularizer= regularizers.l1(0.006), 
          activation= 'relu'),
    
    Dropout(rate= 0.45, 
            seed= 123),
    
    Dense(class_count, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 512)               20024384
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 44)                11308
#
# =================================================================
# Total params: 20,169,068
# Trainable params: 20,168,044
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', 
                           patience=5,
                           verbose=1)

checkpoint = ModelCheckpoint('model_weights.h5', 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=True, 
                             mode='min', 
                             verbose=1)


history = model.fit(x= train_gen, 
                    epochs= 200, 
                    callbacks=[early_stop, checkpoint],
                    validation_data= valid_gen)
# Out:
# Epoch 1/200
# 98/98 [==============================] - ETA: 0s - loss: 8.3420 - accuracy: 0.1445
# Epoch 1: val_loss improved from inf to 9.02097, saving model to model_weights.h5
# 98/98 [==============================] - 89s 616ms/step - loss: 8.3420 - accuracy: 0.1445 - val_loss: 9.0210 - val_accuracy: 0.1176
# Epoch 2/200
# 98/98 [==============================] - ETA: 0s - loss: 6.6890 - accuracy: 0.2597
# Epoch 2: val_loss improved from 9.02097 to 6.92295, saving model to model_weights.h5
# 98/98 [==============================] - 51s 516ms/step - loss: 6.6890 - accuracy: 0.2597 - val_loss: 6.9229 - val_accuracy: 0.0774
# Epoch 3/200
# 98/98 [==============================] - ETA: 0s - loss: 5.7654 - accuracy: 0.3149
# Epoch 3: val_loss improved from 6.92295 to 5.94883, saving model to model_weights.h5
# 98/98 [==============================] - 51s 519ms/step - loss: 5.7654 - accuracy: 0.3149 - val_loss: 5.9488 - val_accuracy: 0.1949
# Epoch 4/200
# 98/98 [==============================] - ETA: 0s - loss: 5.0318 - accuracy: 0.3631
# Epoch 4: val_loss improved from 5.94883 to 5.68354, saving model to model_weights.h5
# 98/98 [==============================] - 51s 519ms/step - loss: 5.0318 - accuracy: 0.3631 - val_loss: 5.6835 - val_accuracy: 0.1399
# Epoch 5/200
# 98/98 [==============================] - ETA: 0s - loss: 4.4722 - accuracy: 0.4043
# Epoch 5: val_loss improved from 5.68354 to 5.11977, saving model to model_weights.h5
# 98/98 [==============================] - 51s 517ms/step - loss: 4.4722 - accuracy: 0.4043 - val_loss: 5.1198 - val_accuracy: 0.2009
# Epoch 6/200
# 98/98 [==============================] - ETA: 0s - loss: 3.9947 - accuracy: 0.4330
# Epoch 6: val_loss improved from 5.11977 to 4.41902, saving model to model_weights.h5
# 98/98 [==============================] - 51s 518ms/step - loss: 3.9947 - accuracy: 0.4330 - val_loss: 4.4190 - val_accuracy: 0.2827
# Epoch 7/200
# 98/98 [==============================] - ETA: 0s - loss: 3.6127 - accuracy: 0.4690
# Epoch 7: val_loss did not improve from 4.41902
# 98/98 [==============================] - 51s 515ms/step - loss: 3.6127 - accuracy: 0.4690 - val_loss: 4.5225 - val_accuracy: 0.2068
# Epoch 8/200
# 98/98 [==============================] - ETA: 0s - loss: 3.2983 - accuracy: 0.4882
# Epoch 8: val_loss improved from 4.41902 to 4.24463, saving model to model_weights.h5
# 98/98 [==============================] - 51s 523ms/step - loss: 3.2983 - accuracy: 0.4882 - val_loss: 4.2446 - val_accuracy: 0.4985
# Epoch 9/200
# 98/98 [==============================] - ETA: 0s - loss: 3.0050 - accuracy: 0.5265
# Epoch 9: val_loss improved from 4.24463 to 3.54573, saving model to model_weights.h5
# 98/98 [==============================] - 51s 524ms/step - loss: 3.0050 - accuracy: 0.5265 - val_loss: 3.5457 - val_accuracy: 0.3884
# Epoch 10/200
# 98/98 [==============================] - ETA: 0s - loss: 2.7901 - accuracy: 0.5507
# Epoch 10: val_loss improved from 3.54573 to 3.23652, saving model to model_weights.h5
# 98/98 [==============================] - 51s 519ms/step - loss: 2.7901 - accuracy: 0.5507 - val_loss: 3.2365 - val_accuracy: 0.4762
# Epoch 11/200
# 98/98 [==============================] - ETA: 0s - loss: 2.5616 - accuracy: 0.5839
# Epoch 11: val_loss improved from 3.23652 to 3.01645, saving model to model_weights.h5
# 98/98 [==============================] - 51s 518ms/step - loss: 2.5616 - accuracy: 0.5839 - val_loss: 3.0164 - val_accuracy: 0.4152
# Epoch 12/200
# 98/98 [==============================] - ETA: 0s - loss: 2.3619 - accuracy: 0.6136
# Epoch 12: val_loss improved from 3.01645 to 2.47125, saving model to model_weights.h5
# 98/98 [==============================] - 51s 517ms/step - loss: 2.3619 - accuracy: 0.6136 - val_loss: 2.4712 - val_accuracy: 0.5952
# Epoch 13/200
# 98/98 [==============================] - ETA: 0s - loss: 2.2262 - accuracy: 0.6404
# Epoch 13: val_loss did not improve from 2.47125
# 98/98 [==============================] - 51s 518ms/step - loss: 2.2262 - accuracy: 0.6404 - val_loss: 2.6023 - val_accuracy: 0.6176
# Epoch 14/200
# 98/98 [==============================] - ETA: 0s - loss: 2.1042 - accuracy: 0.6567
# Epoch 14: val_loss did not improve from 2.47125
# 98/98 [==============================] - 51s 520ms/step - loss: 2.1042 - accuracy: 0.6567 - val_loss: 2.5571 - val_accuracy: 0.6548
# Epoch 15/200
# 98/98 [==============================] - ETA: 0s - loss: 1.9510 - accuracy: 0.6892
# Epoch 15: val_loss improved from 2.47125 to 2.34228, saving model to model_weights.h5
# 98/98 [==============================] - 51s 517ms/step - loss: 1.9510 - accuracy: 0.6892 - val_loss: 2.3423 - val_accuracy: 0.5774
# Epoch 16/200
# 98/98 [==============================] - ETA: 0s - loss: 1.8551 - accuracy: 0.6994
# Epoch 16: val_loss improved from 2.34228 to 2.11550, saving model to model_weights.h5
# 98/98 [==============================] - 51s 519ms/step - loss: 1.8551 - accuracy: 0.6994 - val_loss: 2.1155 - val_accuracy: 0.7024
# Epoch 17/200
# 98/98 [==============================] - ETA: 0s - loss: 1.7447 - accuracy: 0.7227
# Epoch 17: val_loss improved from 2.11550 to 1.88494, saving model to model_weights.h5
# 98/98 [==============================] - 51s 518ms/step - loss: 1.7447 - accuracy: 0.7227 - val_loss: 1.8849 - val_accuracy: 0.6920
# Epoch 18/200
# 98/98 [==============================] - ETA: 0s - loss: 1.6549 - accuracy: 0.7444
# Epoch 18: val_loss did not improve from 1.88494
# 98/98 [==============================] - 51s 517ms/step - loss: 1.6549 - accuracy: 0.7444 - val_loss: 10.2077 - val_accuracy: 0.7039
# Epoch 19/200
# 98/98 [==============================] - ETA: 0s - loss: 1.5917 - accuracy: 0.7534
# Epoch 19: val_loss did not improve from 1.88494
# 98/98 [==============================] - 51s 518ms/step - loss: 1.5917 - accuracy: 0.7534 - val_loss: 2.0682 - val_accuracy: 0.6577
# Epoch 20/200
# 98/98 [==============================] - ETA: 0s - loss: 1.5105 - accuracy: 0.7853
# Epoch 20: val_loss improved from 1.88494 to 1.60108, saving model to model_weights.h5
# 98/98 [==============================] - 51s 519ms/step - loss: 1.5105 - accuracy: 0.7853 - val_loss: 1.6011 - val_accuracy: 0.7351
# Epoch 21/200
# 98/98 [==============================] - ETA: 0s - loss: 1.4125 - accuracy: 0.8054
# Epoch 21: val_loss improved from 1.60108 to 1.54523, saving model to model_weights.h5
# 98/98 [==============================] - 51s 520ms/step - loss: 1.4125 - accuracy: 0.8054 - val_loss: 1.5452 - val_accuracy: 0.7470
# Epoch 22/200
# 98/98 [==============================] - ETA: 0s - loss: 1.3493 - accuracy: 0.8172
# Epoch 22: val_loss did not improve from 1.54523
# 98/98 [==============================] - 51s 520ms/step - loss: 1.3493 - accuracy: 0.8172 - val_loss: 4.7410 - val_accuracy: 0.7470
# Epoch 23/200
# 98/98 [==============================] - ETA: 0s - loss: 1.2722 - accuracy: 0.8382
# Epoch 23: val_loss improved from 1.54523 to 1.43187, saving model to model_weights.h5
# 98/98 [==============================] - 52s 524ms/step - loss: 1.2722 - accuracy: 0.8382 - val_loss: 1.4319 - val_accuracy: 0.7827
# Epoch 24/200
# 98/98 [==============================] - ETA: 0s - loss: 1.2332 - accuracy: 0.8437
# Epoch 24: val_loss did not improve from 1.43187
# 98/98 [==============================] - 51s 514ms/step - loss: 1.2332 - accuracy: 0.8437 - val_loss: 4.7371 - val_accuracy: 0.7560
# Epoch 25/200
# 98/98 [==============================] - ETA: 0s - loss: 1.1900 - accuracy: 0.8606
# Epoch 25: val_loss did not improve from 1.43187
# 98/98 [==============================] - 51s 518ms/step - loss: 1.1900 - accuracy: 0.8606 - val_loss: 1.6894 - val_accuracy: 0.8110
# Epoch 26/200
# 98/98 [==============================] - ETA: 0s - loss: 1.0984 - accuracy: 0.8842
# Epoch 26: val_loss did not improve from 1.43187
# 98/98 [==============================] - 51s 518ms/step - loss: 1.0984 - accuracy: 0.8842 - val_loss: 1.5622 - val_accuracy: 0.7589
# Epoch 27/200
# 98/98 [==============================] - ETA: 0s - loss: 1.0677 - accuracy: 0.8966
# Epoch 27: val_loss improved from 1.43187 to 1.29850, saving model to model_weights.h5
# 98/98 [==============================] - 51s 522ms/step - loss: 1.0677 - accuracy: 0.8966 - val_loss: 1.2985 - val_accuracy: 0.8229
# Epoch 28/200
# 98/98 [==============================] - ETA: 0s - loss: 1.0325 - accuracy: 0.9011
# Epoch 28: val_loss improved from 1.29850 to 1.27063, saving model to model_weights.h5
# 98/98 [==============================] - 52s 525ms/step - loss: 1.0325 - accuracy: 0.9011 - val_loss: 1.2706 - val_accuracy: 0.8199
# Epoch 29/200
# 98/98 [==============================] - ETA: 0s - loss: 0.8833 - accuracy: 0.9381
# Epoch 31: val_loss improved from 1.25170 to 1.14389, saving model to model_weights.h5
# 98/98 [==============================] - 51s 519ms/step - loss: 0.8833 - accuracy: 0.9381 - val_loss: 1.1439 - val_accuracy: 0.8497
# Epoch 32/200
# 98/98 [==============================] - ETA: 0s - loss: 0.8475 - accuracy: 0.9438
# Epoch 33: val_loss improved from 1.14389 to 1.01890, saving model to model_weights.h5
# 98/98 [==============================] - 51s 518ms/step - loss: 0.8150 - accuracy: 0.9480 - val_loss: 1.0189 - val_accuracy: 0.8661
# Epoch 34/200
# 98/98 [==============================] - ETA: 0s - loss: 0.7640 - accuracy: 0.9649
# Epoch 34: val_loss did not improve from 1.01890
# 98/98 [==============================] - 51s 518ms/step - loss: 0.7640 - accuracy: 0.9649 - val_loss: 1.0812 - val_accuracy: 0.8482
# Epoch 35/200
# 98/98 [==============================] - ETA: 0s - loss: 0.7578 - accuracy: 0.9617
# Epoch 35: val_loss did not improve from 1.01890
# 98/98 [==============================] - 51s 520ms/step - loss: 0.7578 - accuracy: 0.9617 - val_loss: 1.1900 - val_accuracy: 0.8646
# Epoch 36/200
# 98/98 [==============================] - ETA: 0s - loss: 0.7159 - accuracy: 0.9655
# Epoch 36: val_loss did not improve from 1.01890
# 98/98 [==============================] - 51s 517ms/step - loss: 0.7159 - accuracy: 0.9655 - val_loss: 1.7844 - val_accuracy: 0.8795
# Epoch 37/200
# 98/98 [==============================] - ETA: 0s - loss: 0.6736 - accuracy: 0.9809
# Epoch 37: val_loss improved from 1.01890 to 1.01165, saving model to model_weights.h5
# 98/98 [==============================] - 51s 518ms/step - loss: 0.6736 - accuracy: 0.9809 - val_loss: 1.0117 - val_accuracy: 0.8661
# Epoch 38/200
# 98/98 [==============================] - ETA: 0s - loss: 0.6495 - accuracy: 0.9828
# Epoch 38: val_loss improved from 1.01165 to 0.99838, saving model to model_weights.h5
# 98/98 [==============================] - 51s 517ms/step - loss: 0.6495 - accuracy: 0.9828 - val_loss: 0.9984 - val_accuracy: 0.8676
# Epoch 39/200
# 98/98 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.9802
# Epoch 39: val_loss did not improve from 0.99838
# 98/98 [==============================] - 51s 517ms/step - loss: 0.6276 - accuracy: 0.9802 - val_loss: 33.3306 - val_accuracy: 0.8854
# Epoch 40/200
# 98/98 [==============================] - ETA: 0s - loss: 0.6096 - accuracy: 0.9869
# Epoch 40: val_loss improved from 0.99838 to 0.97177, saving model to model_weights.h5
# 98/98 [==============================] - 51s 521ms/step - loss: 0.6096 - accuracy: 0.9869 - val_loss: 0.9718 - val_accuracy: 0.8824
# Epoch 41/200
# 98/98 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.9895
# Epoch 41: val_loss improved from 0.97177 to 0.88592, saving model to model_weights.h5
# 98/98 [==============================] - 51s 517ms/step - loss: 0.5848 - accuracy: 0.9895 - val_loss: 0.8859 - val_accuracy: 0.9033
# Epoch 42/200
# 98/98 [==============================] - ETA: 0s - loss: 0.5638 - accuracy: 0.9901
# Epoch 42: val_loss improved from 0.88592 to 0.87248, saving model to model_weights.h5
# 98/98 [==============================] - 52s 534ms/step - loss: 0.5638 - accuracy: 0.9901 - val_loss: 0.8725 - val_accuracy: 0.8929
# Epoch 43/200
# 59/98 [=================>............] - ETA: 18s - loss: 0.5536 - accuracy: 0.9905

# %%
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])

# %%
y_pred = model.predict(test_gen)

y_pred_labels = np.argmax(y_pred, axis=1)

y_true_labels = test_gen.classes

# %%
class_names = list(test_gen.class_indices.keys())

confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, cmap="Blues", annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
report = classification_report(y_true_labels, y_pred_labels, target_names=class_names)

print("Classification Report: ")
print(report)

# %%
report = classification_report(y_true_labels, y_pred_labels, target_names=class_names)

print("Classification Report: ")
print(report)

# %%
base_model1 = tf.keras.applications.inception_v4 import InceptionV4(include_top= False, 
                                                               weights= "imagenet", 
                                                               input_shape= img_shape,
                                                               pooling= 'max')

model1 = Sequential([
    base_model1,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, 
          kernel_regularizer= regularizers.l2(l= 0.016), 
          activity_regularizer= regularizers.l1(0.006),
          bias_regularizer= regularizers.l1(0.006), 
          activation= 'relu'),
    
    Dropout(rate= 0.45, 
            seed= 123),
    
    Dense(class_count, activation= 'softmax')
])

model1.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model1.summary()

# %%
early_stop = EarlyStopping(monitor='val_loss', 
                           patience=5,
                           verbose=1)

checkpoint = ModelCheckpoint('model_weights.h5', 
                             monitor='val_loss', 
                             save_best_only=True, 
                             save_weights_only=True, 
                             mode='min', 
                             verbose=1)


history = model1.fit(x= train_gen, 
                    epochs= 200, 
                    callbacks=[early_stop, checkpoint],
                    validation_data= valid_gen)

# %%
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model1.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model1.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model1.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])

# %%
y_pred = model1.predict(test_gen)

y_pred_labels = np.argmax(y_pred, axis=1)

y_true_labels = test_gen.classes

# %%
class_names = list(test_gen.class_indices.keys())

confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, cmap="Blues", annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
report = classification_report(y_true_labels, y_pred_labels, target_names=class_names)

print("Classification Report: ")
print(report)
